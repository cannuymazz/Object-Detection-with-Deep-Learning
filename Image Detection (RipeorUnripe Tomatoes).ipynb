# %%
import torch
torch.cuda.current_device()
torch.cuda.device(0)
torch.cuda.device_count()
torch.cuda.get_device_name(0)
torch.cuda.is_available()

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from YAML
model = YOLO(r"C:\Users\cannu\Desktop\Tomato_Detection\yolov8n.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolov8n.yaml").load(r"C:\Users\cannu\Desktop\Tomato_Detection\yolov8n.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data=r"C:\Users\cannu\Desktop\Tomato_Detection\data.yaml", epochs=30, imgsz=640, verbose=True)

# %%
from ultralytics import YOLO

# Load a model
model = YOLO(r"C:\Users\cannu\Desktop\Tomato_Detection\yolov8n.pt")  # load an official model
model = YOLO(r"C:\Users\cannu\runs\detect\train2\weights\best.pt")  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.221 🚀 Python-3.11.5 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# YOLOv8n summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\cannu\Desktop\Tomato_Detection\valid\labels.cache... 108 images, 0 backgrounds, 0 corrupt: 100%|
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:05<0
#                    all        108        341      0.862      0.868      0.898      0.598
#                   ripe        108         25       0.93          1      0.995      0.706
#               semiripe        108         38      0.869        0.7      0.793      0.534
#                 unripe        108        278      0.787      0.903      0.905      0.554
# Speed: 2.0ms preprocess, 6.7ms inference, 0.0ms loss, 5.3ms postprocess per image
# Results saved to runs\detect\val8
# array([     0.7062,     0.53411,     0.55395])

# %%
from ultralytics import YOLO

# Load a model
model = YOLO(r"C:\Users\cannu\Desktop\Tomato_Detection\yolov8n.pt")  # load an official model
model = YOLO(r"C:\Users\cannu\runs\detect\train2\weights\best.pt")  # load a custom model

# %%
results = model(r"C:\Users\cannu\Desktop\greenhousetomatoes.mp4")  # predict on an image

# %%
from PIL import Image

# %%
import cv2

# %%
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    im.show()  # show image
    im.save('results.mp4')

# %%
video_path = r"C:\Users\cannu\Desktop\videoplayback (3).mp4"
cap = cv2.VideoCapture(video_path)
crop_count=0
# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model(frame, conf=0.45)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()
        boxes = results[0].boxes.xyxy.cpu()

        for box in boxes:
            crop_count += 1
            crop_object = frame[int(box[1]):int(box[3]), int(box[0]):int(box[2])]
            cv2.imwrite(r"C:\Users\cannu\Desktop\yy\n"+str(crop_count)+".png", crop_object)
        
        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)
        
        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 unripe, 15.5ms
# Speed: 417.8ms preprocess, 15.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.9ms
# Speed: 8.4ms preprocess, 15.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.4ms
# Speed: 2.4ms preprocess, 14.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.5ms
# Speed: 3.0ms preprocess, 18.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.1ms
# Speed: 2.9ms preprocess, 11.1ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ripe, 13.9ms
# Speed: 0.0ms preprocess, 13.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.6ms
# Speed: 3.5ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.8ms
# ...
